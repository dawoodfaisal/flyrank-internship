# %% [markdown]
# <a href="https://colab.research.google.com/github/dawoodfaisal/flyrank-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dawoodfaisal/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter

# %%
import os

print(os.path.exists("flyrank-ml-internship-starter"))
print(os.listdir())
# Out:
# False
# ['SETUP.md', 'LICENSE', 'README.md', 'DATA_USE.md', 'work', '.git', 'submission', 'requirements.txt', '.gitignore', 'scripts', 'docs', 'GUIDE.md', 'data', 'skills', 'notebooks', 'CLAUDE.md', 'outputs', 'AGENTS.md', '.github']

# %%
import os
import subprocess
import pandas as pd

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL], check=True)

os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
# Out:
# Current directory: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Total pages: 30000

# %%
## 1. My Lane (or Freestyle) and Why

I chose the **Content Refresh Prediction** lane because it focuses on identifying webpages that may be declining in performance and need to be updated. This project is interesting because it can help prioritise which pages should be reviewed first instead of checking every page manually. Machine learning can support this decision by analysing multiple signals from the data.
# Out:
#   File "/tmp/ipykernel_480/544233551.py", line 3
#     I chose the **Content Refresh Prediction** lane because it focuses on identifying webpages that may be declining in performance and need to be updated. This project is interesting because it can help prioritise which pages should be reviewed first instead of checking every page manually. Machine learning can support this decision by analysing multiple signals from the data.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
## 2. The Question: Decision, Action, Cost of a Wrong Call

**Research Question:**
Can we identify webpages that are likely to decline so they can be reviewed before losing traffic?

**Decision:**
Which webpages should be prioritised for content refresh?

**Action:**
An SEO or content team reviews and updates the highest-priority pages.

**Cost of a Wrong Recommendation:**
If a healthy page is selected, time and effort are wasted. If a declining page is missed, traffic may continue to decrease and the page may lose visibility.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
## 3. Quick Look at the Data

The starter dataset contains thousands of anonymised webpages with information such as impressions, search volume, CTR, and trend direction. These statistics help show why predicting content that may need refreshing is a useful problem to investigate.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Total pages:", len(df))
print("\nTrend Direction:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 3))
# Out:
# Total pages: 30000
#
# Trend Direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.511

# %%
## 4. Careful Words

This project can identify patterns and provide decision support based on the available data. Any findings will be observations from this dataset and should not be interpreted as proof of how search engines work. The model may help prioritise pages for review, but it cannot predict Google's algorithm or guarantee future rankings.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
